# %% [markdown]
# <a href="https://colab.research.google.com/github/eshnikaaggarwal/HuggingFace_Langchain_integration/blob/main/hugginface_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-huggingface #new library

# %%
# !pip install huggingface-hub #for API calls

# %%
#for API calls
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 8.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # HuggingFaceEndpoint
# **How o call a Huggingface Model with API**
# 1. download the model directly into my colab, for which we need big resources
# 2. call the model via end points , which we will be doing

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key= userdata.get('HF_API_TOKEN')
print("Secret key for huggingface_hub: ",sec_key)
# Out:
# Secret key for huggingface_hub:  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

# %%
#set up my HF token
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]= sec_key

# %%
#which model i want to call
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
# Remove the 'token' parameter here. It should automatically use the environment variable.
llm=HuggingFaceEndpoint(repo_id=repo_id, max_length=128,temperature=0.7)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.

# %%
llm.invoke("what is machine learning")   #for calling the model
# Out:
# '?\n\nMachine learning (ML) is a subset of artificial intelligence (AI) that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. It focuses on the development of computer programs that can access data and use it to learn for themselves.\n\nThe process of learning begins with observations or data, such as examples, direct experience, or instruction, in order to look for patterns in data and make better decisions in the future based on the examples that we provide. The primary aim is to allow the computers to learn automatically without human intervention or assistance and adjust actions accordingly.\n\nMachine learning algorithms are used in a wide range of applications, such as email filtering, detection of network intruders, and computer vision, where it is infeasible to develop a conventional algorithm to perform the task.\n\nThere are three main types of machine learning: supervised learning, unsupervised learning, a
# ...

# %%
question="Who won the cricket world Cup in the year 2011?"
template = """Question :{question}
Answer: Let's think step by step"""

prompt=PromptTemplate(template=template,input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question :{question}\nAnswer: Let's think step by step"

# %%
from langchain import PromptTemplate, LLMChain

question="Who won the cricket world Cup in the year 2011?"
template = """Question :{question}
Answer: Let's think step by step"""

prompt=PromptTemplate(template=template,input_variables=["question"])
llm_chain=LLMChain(prompt=prompt,llm=llm)
print(llm_chain.run(question))   # or instead of 'run' could write 'invoke'
# Out:
# <ipython-input-17-5c2ce8bbdaa2>:8: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain=LLMChain(prompt=prompt,llm=llm)
# <ipython-input-17-5c2ce8bbdaa2>:9: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   print(llm_chain.run(question))
#  -
# 1. The Cricket World Cup is held every four years.
# ...

# %% [markdown]
# # HuggingFace Pipeline
# download entire model in local hardware

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline # Fixed typo here

# %%
model_id="gpt2"
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",model=model,tokenizer= tokenizer,max_new_tokens = 100)
hf= HuggingFacePipeline(pipeline=pipe)
# Out:
# Device set to use cpu

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7af3000ae490>, model_id='gpt2')

# %%
hf.invoke("Langchain is a company")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "Langchain is a company that manufactures a special, inexpensive, easy to use and easy to use chip that works seamlessly with all modern PCs. The first chip to go through the process is a single silicon chip with a single chip core. And it's really, really easy to use – there are no more tools to hack those chips, just basic data storage and so forth. You can read our review here, as well as our full review of the same chip at RIAA.\n\nIn any case, when it"

# %%
## Use HuggingFace Pipelines along with GPUs or CPU if no GPU is available
try:
    import torch
    if torch.cuda.is_available():
        device = 0  # Use the first GPU if available
    else:
        device = -1 # Use CPU if no GPU is available
except ImportError:
    device = -1  # Use CPU if torch is not installed

gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device=device,
    pipeline_kwargs={"max_new_tokens": 100}
)
# Out:
# Device set to use cpu

# %%
from langchain_core.prompts import PromptTemplate
#from langchain_core.chat_models import ChatOpenAI
#from langchain_core.chains import LLMChain

template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
llm_chain = LLMChain(prompt=prompt, llm=gpu_llm)
question = "What NFL team won the Super Bowl in the year Justin Beiber was born?"
result = llm_chain.run(question)  # Store the result
print(result)
# Out:
# Question: What NFL team won the Super Bowl in the year Justin Beiber was born?
# Answer: Let's think step by step. For three years, we kept the Super Bowl title race close under our belts.
# What we thought about, and how we looked at that, were these players: Mike Wallace & Tevin Coleman? How could this be different in 2017? If we had a running game like that right now, we'd have a hard core out there. But now, we want to do something that is different.
# We looked at a lot of different players and they were like, "Why? You didn't
